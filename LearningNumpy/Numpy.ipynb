# %% [markdown]
# # Learning Numpy

# %%
import numpy as np

# %%
print("Pranshul")
# Out:
# Pranshul

# %%
myarr = np.array([[1,2,3,4]])

# %%
myarr
# Out:
# array([[1, 2, 3, 4]])

# %%
myarr[0,2]
# Out:
# np.int64(3)

# %%
myarr.shape
# Out:
# (1, 4)

# %%
myarr.dtype
# Out:
# dtype('int64')

# %%
myarr[0,2] = 5

# %%
myarr
# Out:
# array([[1, 2, 5, 4]])
